# %% [markdown]
# # Klasifikasi Jenis Sampah - CNN
# Input → Conv → ReLU → Pool → Flatten → Fully Connected → Softmax

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Rescaling
from tensorflow.keras.preprocessing import image_dataset_from_directory
import numpy as np

# %% [markdown]
# ## Load Dataset

# %%
dataset_path = "TrashType_Image_Dataset"

train_ds = image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(128, 128),
    batch_size=32
)

val_ds = image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=(128, 128),
    batch_size=32
)

class_names = train_ds.class_names
print("Kelas:", class_names)
# Out:
# Found 2527 files belonging to 6 classes.
# Using 2022 files for training.
# Found 2527 files belonging to 6 classes.
# Using 505 files for validation.
# Kelas: ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %% [markdown]
# ## CNN Model

# %%
model = Sequential([
    Rescaling(1./255, input_shape=(128,128,3)),

    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D((2,2)),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D((2,2)),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D((2,2)),

    Flatten(),

    Dense(128, activation='relu'),

    Dense(len(class_names), activation='softmax')
])

model.summary()
# Out:
# c:\semester 6\Week 12 CNN\tfenv\Lib\site-packages\keras\src\layers\preprocessing\data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ...

# %% [markdown]
# ## Compile Model

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ## Training

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=15
)
# Out:
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 23s 327ms/step - accuracy: 0.3645 - loss: 1.5063 - val_accuracy: 0.4257 - val_loss: 1.4022
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 24s 380ms/step - accuracy: 0.5020 - loss: 1.2397 - val_accuracy: 0.5703 - val_loss: 1.1677
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 38s 333ms/step - accuracy: 0.5806 - loss: 1.0858 - val_accuracy: 0.5941 - val_loss: 1.0955
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 22s 338ms/step - accuracy: 0.6672 - loss: 0.9204 - val_accuracy: 0.5347 - val_loss: 1.3595
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 322ms/step - accuracy: 0.6924 - loss: 0.8176 - val_accuracy: 0.6396 - val_loss: 1.0245
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 318ms/step - accuracy: 0.7789 - loss: 0.6228 - val_accuracy: 0.5545 - val_loss: 1.2522
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 306ms/step - accuracy: 0.8447 - loss: 0.4404 - val_accuracy: 0.6277 - val_loss: 1.6180
# Epoch 8/15
# ...

# %% [markdown]
# ## Evaluasi

# %%
loss, acc = model.evaluate(val_ds)

print("Validation Accuracy:", acc)
print("Validation Loss:", loss)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.6634 - loss: 2.0835
# Validation Accuracy: 0.6633663177490234
# Validation Loss: 2.083519220352173

# %% [markdown]
# ## Prediksi Gambar Baru

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
import os

# pilih salah satu gambar untuk diuji
img_path = r"TrashType_Image_Dataset\metal\metal_282.jpg"

# cek apakah file ada
print(os.path.exists(img_path))

img = load_img(img_path, target_size=(128,128))
img_array = img_to_array(img)

img_array = img_array / 255.0
img_array = np.expand_dims(img_array, axis=0)

prediction = model.predict(img_array)

predicted_class = class_names[np.argmax(prediction)]

print("Jenis Sampah :", predicted_class)
print("Probabilitas :", np.max(prediction))
# Out:
# True
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# Jenis Sampah : glass
# Probabilitas : 0.99999595
